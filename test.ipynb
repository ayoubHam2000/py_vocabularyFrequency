# %%
import pandas as pd

from nltk import FreqDist
import re


from nltk.stem.wordnet import WordNetLemmatizer
from nltk import FreqDist
import enchant
import nltk
from pattern.text.en import singularize

# %%
df = pd.read_csv('out_1.txt', sep=' : ', engine='python')

# %%
#get frequency of frequency 
f = df["frequency"].value_counts()
f.to_csv('frequency_number.txt')

# %%
acc = f.cumsum(axis = 0)
acc.to_csv('frequency_number_acc.txt')

# %%
words = df["word"]
words.to_csv('words.txt', index=False)

# %%
d = "cloaks"
print(singularize(d))
tokenized = nltk.word_tokenize(d)
nltk.pos_tag(tokenized)
# Out:
# cloak
# [('cloaks', 'NNS')]

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("missed", 'v')
# Out:
# 'miss'

# %%
lemmatizer = WordNetLemmatizer()
dicts = enchant.Dict("en_US")
dic = {}
l = len(df["word"])
for i in range(0, l):
    word = df["word"][i]
    fre = df["frequency"][i]
    tokenized = nltk.word_tokenize(word)
    for (w, pos) in nltk.pos_tag(tokenized):
        item = w
        if not dicts.check(item):
            continue
        if(pos[:2] == 'NN'):
            item = singularize(w)
        elif(pos[:2] == 'VB'):
            infi = lemmatizer.lemmatize(w, 'v')
            item = infi
        if not item in dic:
            dic[item] = fre
        else:
            dic[item] += fre
        if word != item and not dicts.check(item) and dicts.check(word):
            print(f'{word} => {item}')
dic = dict(sorted(dic.items(), key=lambda item: item[1]))
# Out:
# congress => congres
# downpour => downpmy
# sleepiness => sleepines
# discus => discu
# sleepless => sleeples
# specimen => speciman
# p-p-petunia => p-p-petunium
# twenty-four => twenty-fmy
# circus => circu
# eyeglass => eyeglas
# loss => los
# heartstrings => heartstring
# depress => depres
# dreadlocks => dreadlock
# chorus => choru
# useless => useles
# confess => confes
# greatness => greatnes
# pies => py
# shapeless => shapeles
# bonus => bonu
# versus => versu
# mattress => mattres
# restless => restles
# dives => dife
# chipolata => chipolatum
# slice => slouse
# sadness => sadnes
# endless => endles
# opus => opu
# bias => bia
# tennis => tenni
# harness => harnes
# hourglass => hourglas
# defenseless => defenseles
# forgetfulness => forgetfulnes
# motionless => motionles
# omen => oman
# bloodiness => bloodines
# impress => impres
# crisis => crisi
# cleverness => clevernes
# blackness => blacknes
# fuss => fus
# careless => careles
# headmistress => headmistres
# ...

# %%
for item in dic.keys() :
    o = f'{item} : {dic[item]}'
    print(o)
# Out:
# owl-free : 1
# bird-watcher : 1
# newscaster : 1
# weatherman : 1
# beady-eyed : 1
# severe-looking : 1
# s-s-sorry : 1
# carousel : 1
# skinnier : 1
# whats-her-name : 1
# sp-spoil : 1
# mid-jump : 1
# cabbage-smelling : 1
# cobra : 1
# man-crushing : 1
# amigo : 1
# longest-ever : 1
# whelk : 1
# bawling : 1
# gloomy-looking : 1
# multilevel : 1
# rowboat : 1
# gorgon : 1
# dratted : 1
# dormouse : 1
# bungler : 1
# crikey : 1
# d-defense : 1
# d-d-dark : 1
# g-getting : 1
# g-got : 1
# p-pick : 1
# b-book : 1
# m-myself : 1
# self-stirring : 1
# pick-me-up : 1
# chopped : 1
# duffer : 1
# tongue-tying : 1
# viridian : 1
# glittery-black : 1
# swishy : 1
# pliable : 1
# bendy : 1
# right-handed : 1
# beechwood : 1
# funny-shaped : 1
# red-headed : 1
# tenpin : 1
# woodcraft : 1
# booger-flavored : 1
# sniffy : 1
# jell-o : 1
# half-and-half : 1
# all-muggle : 1
# n-nothing : 1
# scabby : 1
# caput : 1
# conk : 1
# talking-to : 1
# wand-waving : 1
# aconite : 1
# porcupine : 1
# ...

# %%
dicts = enchant.Dict("en_US")
dicts.check("bodiless")
# Out:
# True

# %%
from functions import *

def filterWords(data):
    lemmatizer = WordNetLemmatizer()
    dic = enchant.Dict("en_US")
    tokenized = nltk.word_tokenize(data)

    #print(nltk.pos_tag(tokenized))
    result = []
    

    wordType = []
    for (word, pos) in nltk.pos_tag(tokenized):
        t = nltk.word_tokenize(word)
        for (w, p) in nltk.pos_tag(t):
            wordType.append((w, p[:2]))

    for word, pos in wordType:
        item = word
        if not dic.check(item) or not isWordValide(item):
            continue
        if(pos == 'NN'):
            item = singularize(item)
        elif(pos == 'VB'):
            item = lemmatizer.lemmatize(word, 'v')
        else:
            item = word

        if word != item and not dic.check(item):
            result.append(word)
        else:
            result.append(item)
    return result


word_dist = FreqDist()

f = 'texts/01 Harry Potter and the Sorcerer\'s Stone.txt'
formatedText = getFormatText(f)
words = filterWords(formatedText)
word_dist.update(words)
print(f'{f} --- > Done')

result = dict(word_dist)
result = dict(sorted(result.items(), key=lambda item: item[1]))
for item in result.keys() :
    o = f'{item} : {result[item]}'
    print(o)
# Out:
# texts/01 Harry Potter and the Sorcerer's Stone.txt --- > Done
# prisoner : 1
# half-blood : 1
# deathly : 1
# hallow : 1
# imprint : 1
# di : 1
# publish : 1
# division : 1
# logo : 1
# register : 1
# character : 1
# publication : 1
# reproduce : 1
# retrieval : 1
# system : 1
# transmit : 1
# electronic : 1
# mechanical : 1
# photocopy : 1
# regard : 1
# york : 1
# congress : 1
# cataloging-in-publication : 1
# datum : 1
# cm : 1
# summary : 1
# outrageous : 1
# neglect : 1
# attend : 1
# fantasy : 1
# edition : 1
# beefy : 1
# amount : 1
# fence : 1
# good-for-nothing : 1
# husband : 1
# gossiped : 1
# briefcase : 1
# pecked : 1
# cereal : 1
# enrage : 1
# stunt : 1
# ninth : 1
# open-mouthed : 1
# owl-free : 1
# bakery : 1
# baker : 1
# whisperer : 1
# secretary : 1
# receiver : 1
# squeaky : 1
# rejoice : 1
# approve : 1
# driveway : 1
# shoo : 1
# behavior : 1
# daughter : 1
# bird-watcher : 1
# nation : 1
# sighting : 1
# sunrise : 1
# expert : 1
# pattern : 1
# newscaster : 1
# ...
