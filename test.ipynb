# %%
import pandas as pd
import re
from nltk import FreqDist
import glob
from nltk.stem.wordnet import WordNetLemmatizer
import enchant
import nltk
from pattern.text.en import singularize
import spacy

# %%
df = pd.read_csv('out/all_final.txt', sep=' : ', engine='python')

# %%
#get frequency of frequency 
f = df["frequency"].value_counts()
f.to_csv('frequency_number.txt')

# %%
acc = len(df["frequency"]) - f.cumsum(axis = 0)
acc
#acc.to_csv('frequency_number_acc.txt')
# Out:
# 1       19907
# 2       17052
# 3       15193
# 4       13842
# 5       12784
#         ...
# 409         4
# 425         3
# 1474        2
# 4555        1
# 1983        0
# Name: frequency, Length: 1123, dtype: int64

# %%
words = df["word"]
words.to_csv('words.txt', index=False)

# %%
d = "called"
print(singularize(d))
tokenized = nltk.word_tokenize(d)
nltk.pos_tag(tokenized)
# Out:
# called
# [('called', 'VBN')]

# %%
# get word type
nlp = spacy.load("en_core_web_sm")
text = ("call")
doc = nlp(text)
verbs = [(token, token.tag_) for token in doc]
verbs
# Out:
# [(call, 'VB')]

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("ridden", 'v')
# Out:
# 'ride'

# %%
dicts = enchant.Dict("en_US")
dicts.check("bodiless")
# Out:
# True

# %%
def isWordValide(word):
    return (not re.search(r"\d+", word)) and len(word) > 1

def single(word, dic):
    w = singularize(word)
    if word != w and dic.check(w):
        #print(f'{word} => {w}')
        return w
    return word

def origin(word, dic, lemmatizer):
    w = lemmatizer.lemmatize(word, 'v')
    if word != w and dic.check(w):
        #print(f'{word} => {w}')
        return w
    return single(word, dic)

def getFormatText(file):
    data = open(file).read().lower()
    data = re.sub(r'[^\x20-\x7F]+', '', data)
    data = re.sub(r'-\n', '', data)
    data = re.sub(r'\n+', ' ', data)
    data = re.sub(r'-', ' ', data)
    data = re.sub(r'\d+', '', data)
    data = re.sub(r'[?./!;,:*-+{}\[\]\\@#$%^&()_`~‘’]|“|”', '', data)
    data = re.sub(r' +', ' ', data)
    #data = re.sub(r'\W\d+\W', '', data)
    return data

def getWords(file):
    data = getFormatText(file)
    return [item.strip() for item in data.split(' ') if item.strip()]

def getWordsFrequencies(files):
    #nltk.download('punkt')
    word_dist = FreqDist()
    dicts = enchant.Dict("en_US")
    for f in files: 
        words = getWords(f)
        for item in words:
            if dicts.check(item) and isWordValide(item):
                word_dist.update([item])
    result = dict(word_dist)
    #result = dict(sorted(result.items(), key=lambda item: item[1]))
    return result

def getOrigins(wordFreq):
    lemmatizer = WordNetLemmatizer()
    dic = enchant.Dict("en_US")

    res = {}
    for item in wordFreq.keys():
        try:
            o = origin(item, dic, lemmatizer)
            if o not in res:
                res[o] = wordFreq[item]
            else:
                res[o] += wordFreq[item]
        except:
            print(item)
        
    res = dict(sorted(res.items(), key=lambda item: item[1]))
    return res

# %%
#get the word frequency
files = glob.glob("texts/sub/*")
i = 0
for file in files:
    i += 1
    wordFreq = getWordsFrequencies([file])
    wordFreq = dict(sorted(wordFreq.items(), key=lambda item: item[1]))

    out_file = open(f'out/subs/s_{i}.txt', 'w')
    out_file.write(f'{file}\n')
    out_file.write('word : frequency\n')
    for item in wordFreq.keys():
        out_file.write(f'{item} : {wordFreq[item]}\n')
# texts/sub\The.Big.Bang.Theory.S11E23.The.Sibling.Realignment.720p.WEB-DL.x264.AAC.srt --- > Done
# 239
# texts/sub\The.Big.Bang.Theory.S11E24.The.Bow.Tie.Asymmetry.720p.WEB-DL.x264.AAC.srt --- > Done
# 240
# texts/sub\The.Leftovers.S02E01.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 241
# texts/sub\The.Leftovers.S02E02.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 242
# texts/sub\The.Leftovers.S02E03.720p.BluRay.x264.AAC2.0-Pahe.inen.srt --- > Done
# 243
# texts/sub\The.Leftovers.S02E04.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 244
# texts/sub\The.Leftovers.S02E05.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 245
# texts/sub\The.Leftovers.S02E06.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 246
# texts/sub\The.Leftovers.S02E07.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 247
# texts/sub\The.Leftovers.S02E08.720p.BluRay.x264.AAC2.0-Pahe.in-en.srt --- > Done
# 248
# texts/sub\The.Leftovers.S02E09.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 249
# texts/sub\The.Leftovers.S02E10.720p.BluRay.x264.AAC2.0-Pahe.in.en.srt --- > Done
# 250
# texts/sub\The.Office.US.S01E01.Pilot.WEBRip.x264-FGT.srt --- > Done
# 251
# texts/sub\The.Office.US.S01E02.Diversity.Day.WEBRip.x264-FGT.srt --- > Done
# 252
# texts/sub\The.Office.US.S01E03.Health.Care.WEBRip.x264-FGT.srt --- > Done
# 253
# texts/sub\The.Office.US.S01E04.The.Alliance.WEBRip.x264-FGT.srt --- > Done
# 254
# texts/sub\The.Office.US.S01E05.Basketball.WEBRip.x264-FGT.srt --- > Done
# 255
# texts/sub\The.Office.US.S01E06.Hot.Girl.WEBRip.x264-FGT.srt --- > Done

# %%
files = glob.glob("out/final/*")
allWords = {}
for f in files:
    df = pd.read_csv(f, sep=' : ', engine='python', skiprows=[])
    for index, row in df.iterrows():
        word = row['word']
        frequency = row['frequency']
        if word not in allWords:
            allWords[word] = frequency
        else:
            allWords[word] += frequency
    print(f'{f}-{len(df["word"])} --> Done')
len(allWords)
# Out:
# out/final\final_words.txt-23106 --> Done
# out/final\final_words_subs.txt-12573 --> Done
# 25284

# %%
#write the All words
allWords = dict(sorted(allWords.items(), key=lambda item: item[1]))
out_file = open('out/all_final.txt', 'w')
out_file.write('word : frequency\n')
for item in allWords.keys():
    out_file.write(f'{item} : {allWords[item]}\n')
len(allWords)
# Out:
# 25284

# %%
#origin words

final_words = pd.read_csv('out/all_words_subs.txt', sep=' : ', engine='python')
out_file = open('out/final_words_subs.txt', 'w')
out_file.write('word : frequency\n')

test = {}
for index, row in final_words.iterrows():
    word = row['word']
    frequency = row['frequency']
    test[word] = frequency
print(len(final_words['word']))
print(len(test))

final_words = getOrigins(test)
print(len(final_words))

out_file.write('word : frequency\n')
for item in final_words.keys():
    out_file.write(f'{item} : {final_words[item]}\n')
# Out:
# 17708
# 17708
# nan
# 12573
